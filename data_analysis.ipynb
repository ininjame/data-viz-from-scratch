# %%
import pandas as pd

df = pd.read_csv(r"data\pay-gap\occupation-hourly-pay-by-gender-2017.csv")

# %%
df
# Out:
#     job_type_code  job_subtype_code  \
# 0               1                11
# 1               1                12
# 2               2                21
# 3               2                22
# 4               2                23
# 5               2                24
# 6               3                31
# 7               3                32
# 8               3                33
# 9               3                34
# 10              3                35
# 11              4                41
# 12              4                42
# 13              5                51
# 14              5                52
# 15              5                53
# 16              5                54
# 17              6                61
# 18              6                62
# 19              7                71
# 20              7                72
# 21              8                81
# 22              8                82
# 23              9                91
# 24              9                92
#
# ...
